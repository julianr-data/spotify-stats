# %%
'''FUNCION QUE TOMA DFS DE TOP ARTISTS Y TRACKS Y DEVUELVE INPUT PARA UN PIE/SUNBURST'''

'''
El resultado es un df final que lista generos, y artistas por genero escuchado.
Idealmente tambien bajaria al nivel cancion, pero el genero por cancion no viene en la API.
Entonces necesito:

Pop: dua lipa, ariana, fito
Rock: charly, juanse, fito
'''

'''
explicar que le procedimiento seria:
1. Tomar df de largo plazo de tracks
2. Por cada item, intentar tomar genero
3. Si genero = NaN ir al df largo plazo de artistas, buscar le artista, unpack & append los generos

pero de acuerdo a lo que dice aca:
https://github.com/spotify/web-api/issues/157
(y a otros posts viejos hasta el 2015 incluso)

lso endpoints de album no tienen genero ni lo han tenido nunca (probabelmente por politicas 
internas de spoty no quieren exponerlos en la api, o directamente porque ni lo usan), de forma que
la unica alternativa es ver los generos desde el artista
'''

'''
aclarar en la pagina misma que los generos por cancion pueden no ser correctos, dado que spotify 
no da generos por cancion y que entonces realizamos paroximacion en abse a la categorizacion de los artistas

aclarar que existe un porcentaje siggnificativo de artistas, muchas veces conocidos! que no tienen genero para spotify  

'''

'''
5. Armar pie chart (la funcion se armaria en app)

6. Repetimos 2 veces mas la funcion, pasandole los df de mediano y corto plazo
'''

# %%
# imports

import pandas as pd
import numpy as np
import plotly.express as px

df_tr = pd.read_csv("test_csvs/user_top_tracks_long_term_df.csv")
df_art = pd.read_csv("test_csvs/user_top_artists_long_term_df.csv")

# %%
df_art
# Out:
#       type                artist_name
# 0   artist               Taylor Swift  \
# 1   artist                   Dua Lipa
# 2   artist              Ariana Grande
# 3   artist             Lizzy McAlpine
# 4   artist                  Fito Paez
# 5   artist             Justin Hurwitz
# 6   artist                    ROSALÍA
# 7   artist            Julian R. Fogel
# 8   artist                      Opeth
# 9   artist                   Vulfpeck
# 10  artist                The Beatles
# 11  artist                Mon Laferte
# 12  artist                   Lawrence
# 13  artist                  Cory Wong
# 14  artist            Rolando Alarcon
# 15  artist              Billie Eilish
# 16  artist              Charly García
# 17  artist             Britney Spears
# 18  artist                 Pink Floyd
# 19  artist                Iron Maiden
# 20  artist                    Soledad
# 21  artist             Porcupine Tree
# 22  artist               Himesh Patel
# 23  artist           The Barnevelders
# 24  artist                Pedro Aznar
# 25  artist     Destruyan a Los Robots
# 26  artist                 Nick Drake
# 27  artist                    Shakira
# 28  artist               Nicki Nicole
# 29  artist                  Nightwish
# 30  artist                    Pacific
# 31  artist             Regina Spektor
# 32  artist                   Megadeth
# 33  artist  Los Auténticos Decadentes
# 34  artist           System Of A Down
# 35  artist                Soda Stereo
# 36  artist                   Maroon 5
# 37  artist         The Red Army Choir
# 38  artist      Juan Carlos Baglietto
# 39  artist                       ocha
# 40  artist               Eric Clapton
# 41  artist                      Shefa
# 42  artist           Daniel Barenboim
# 43  artist          María Elena Walsh
# 44  artist                     The xx
# 45  artist                  b schmidt
# 46  artist              Leonard Cohen
# 47  artist                   No Doubt
# 48  artist   Crazy Ex-Girlfriend Cast
# 49  artist             Chango Spasiuk
#
#                                                genres  popularity
# 0                                             ['pop']         100  \
# 1                      ['dance pop', 'pop', 'uk pop']          87
# 2                                             ['pop']          89
# 3               ['alt z', 'boston folk', 'indie pop']          75
# 4   ['argentine rock', 'latin alternative', 'latin...          72
# 5          ['hollywood', 'movie tunes', 'soundtrack']          63
# 6                           ['pop', 'r&b en espanol']          86
# 7                                                  []           0
# 8   ['alternative metal', 'metal', 'progressive de...          57
# 9   ['ann arbor indie', 'funk rock', 'instrumental...          61
# 10  ['beatlesque', 'british invasion', 'classic ro...          84
# 11                 ['latin alternative', 'latin pop']          74
# 12                          ['nyc pop', 'retro soul']          50
# 13                              ['instrumental funk']          54
# 14                                  ['nueva cancion']          35
# 15                   ['art pop', 'electropop', 'pop']          88
# 16  ['argentine rock', 'latin alternative', 'latin...          67
# 17                               ['dance pop', 'pop']          80
# 18  ['album rock', 'art rock', 'classic rock', 'pr...          80
# 19           ['hard rock', 'metal', 'nwobhm', 'rock']          73
# 20          ['folklore argentino', 'folklore surero']          59
# 21          ['progressive metal', 'progressive rock']          55
# 22                                                 []          39
# 23                                                 []           0
# 24                ['argentine rock', 'rock nacional']          56
# 25                                                 []           0
# 26  ['british folk', 'folk', 'melancholia', 'singe...          61
# 27  ['colombian pop', 'dance pop', 'latin pop', 'p...          90
# 28  ['argentine hip hop', 'r&b argentino', 'trap a...          80
# 29  ['fantasy metal', 'finnish metal', 'finnish po...          65
# 30                                                 []          45
# 31              ['indie pop', 'lilith', 'piano rock']          61
# 32  ['alternative metal', 'hard rock', 'melodic th...          70
# 33  ['argentine rock', 'latin alternative', 'latin...          67
# 34  ['alternative metal', 'nu metal', 'rap metal',...          80
# 35  ['argentine rock', 'latin alternative', 'latin...          74
# 36                                            ['pop']          85
# 37              ['musique militaire', 'russian folk']          53
# 38  ['argentine rock', 'folklore argentino', 'rock...          50
# 39                                    ['lo-fi beats']          36
# 40  ['album rock', 'blues rock', 'classic rock', '...          72
# 41                                                 []           2
# 42  ['classical', 'classical performance', 'israel...          62
# 43  ['cancion infantil latinoamericana', 'musica p...          48
# 44  ['downtempo', 'dream pop', 'indietronica', 'mo...          66
# 45                                                 []           0
# 46  ['canadian singer-songwriter', 'melancholia', ...          64
# 47  ['dance pop', 'dance rock', 'permanent wave', ...          68
# 48                                                 []          47
# 49                             ['folklore argentino']          40
#
#                                                 image  followers
# 0   https://i.scdn.co/image/ab6761610000e5eb5a0096...          0  \
# 1   https://i.scdn.co/image/ab6761610000e5ebd42a27...          0
# 2   https://i.scdn.co/image/ab6761610000e5ebcdce76...          0
# 3   https://i.scdn.co/image/ab6761610000e5ebb10e2b...          0
# 4   https://i.scdn.co/image/ab6761610000e5eb4366e7...          0
# 5   https://i.scdn.co/image/ab6761610000e5eb152668...          0
# 6   https://i.scdn.co/image/ab6761610000e5ebd7bb67...          0
# 7   https://i.scdn.co/image/ab6761610000e5eb33c35a...          0
# 8   https://i.scdn.co/image/ab6761610000e5eb304044...          0
# 9   https://i.scdn.co/image/ab6761610000e5eb3f8c36...          0
# 10  https://i.scdn.co/image/ab6761610000e5ebe9348c...          0
otify:artist:6qqNVTkY8uBg9cP3Jd7DAH
# 16  spotify:artist:3jO7X5KupvwmWTHGtHgcgo
# 17  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 18  spotify:artist:0k17h0D3J5VfsdmQ1iZtE9
# 19  spotify:artist:6mdiAmATAx73kdxrNrnlao
# 20  spotify:artist:0K59Fm1y7s3j498ueS4qzY
# 21  spotify:artist:5NXHXK6hOCotCF8lvGM1I0
# 22  spotify:artist:7mFiLle487vR83fsFmcKgt
# 23  spotify:artist:0fNbD2JQZjqtjThLWs4QMK
# 24  spotify:artist:2FFrhWZS9vJsh2UvxYPRr6
# 25  spotify:artist:4wsXXEmFF9uwQSOTFKZvs0
# 26  spotify:artist:5c3GLXai8YOMid29ZEuR9y
# 27  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 28  spotify:artist:2UZIAOlrnyZmyzt1nuXr9y
# 29  spotify:artist:2NPduAUeLVsfIauhRwuft1
# 30  spotify:artist:5WLsGgfxV206tL7KD41Ft1
# 31  spotify:artist:3z6Gk257P9jNcZbBXJNX5i
# 32  spotify:artist:1Yox196W7bzVNZI7RBaPnf
# 33  spotify:artist:3HrbmsYpKjWH1lzhad7alj
# 34  spotify:artist:5eAWCfyUhZtHHtBdNk56l1
# 35  spotify:artist:7An4yvF7hDYDolN4m5zKBp
# 36  spotify:artist:04gDigrS5kc9YWfZHwBETP
# 37  spotify:artist:4yNluGAiPbYXLwlA9KspbG
# 38  spotify:artist:1Mt6JeVWV9Tvgk8ercp5O9
# 39  spotify:artist:2XXkRPi7NhXPf4vOPIG9zh
# 40  spotify:artist:6PAt558ZEZl0DmdXlnjMgD
# 41  spotify:artist:6865jgnW89TIjWXr3Cuh33
# 42  spotify:artist:78sEozQOEJxzXegUuqRSgH
# 43  spotify:artist:5gMEZRCMq0gWA3kuCPukEk
# 44  spotify:artist:3iOvXCl6edW5Um0fXEBRXy
# 45  spotify:artist:4aWC4UPxT80hfTn8uInnte
# 46  spotify:artist:5l8VQNuIg0turYE1VtM9zV
# 47  spotify:artist:0cQbJU1aAzvbEmTuljWLlF
# 48  spotify:artist:2Dzk9smBaIfEFjF7T2Gygz
# 49  spotify:artist:0qGRkfnUqWeG49vbCv6rMY

# %%
df_art.columns
# Out:
# Index(['type', 'artist_name', 'genres', 'popularity', 'image', 'followers',
#        'artist_id', 'url', 'uri'],
#       dtype='object')

# %%
''' 
agarrar cada cancionid, ver el artistaid, ver en el df de artistas q generos tiene, poner:
cancion_name1, artista_name1, genero1
cancion_name1, artista_name1, genero2
cancion_name1, artista_name1, genero3
cancion_name2, artista_name1, genero1
cancion_name2, artista_name1, genero2
cancion_name2, artista_name1, genero3
cancion_name3, artista_name2, genero1
cancion_name4, artista_name3, genero1
'''

track_name = []
artist_name = []
genre = []

# %%
import json
trackid_list = df_tr.track_id.tolist()

final_tracklist, final_artistlist, final_genrelist = [], [], []

for trackid in trackid_list:
    trackname = df_tr.loc[df_tr["track_id"] == trackid, "track_name"].to_string(index=False)
    artid = df_tr.loc[df_tr["track_id"] == trackid, "artist_id"].to_string(index=False)
    artname = df_art.loc[df_art["artist_id"] == artid, "artist_name"].to_string(index=False)
    artgenres = df_art.loc[df_art["artist_id"] == artid, "genres"].to_string(index=False)
    if artgenres == "Series([], )" or artgenres == "[]":
        artgenres = ["Uncategorized"]
    else:
        artgenres = artgenres[1:-1].replace("'","").replace(", ", ",").split(",")
    for genre in artgenres:
        final_tracklist.append(trackname)
        final_artistlist.append(artname)
        final_genrelist.append(genre)
    
    print()
    print(artid, trackid)
    print(artname)
    print(trackname)
    print(artgenres)
# Out:
# 6M2wZ9GZgrQXHCFfjv46we 6zrJLhslleCHby0wbUnvVy
# Dua Lipa
# Future Nostalgia
# ['dance pop', 'pop', 'uk pop']
#
# 06HL4z0CvFAxyc27GXpf02 4OAuvHryIVv4kMDNSLuPt6
# Taylor Swift
# Red (Taylor's Version)
# ['pop']
#
# 06HL4z0CvFAxyc27GXpf02 6lzc0Al0zfZOIFsFvBS1ki
# Taylor Swift
# State Of Grace (Taylor's Version)
# ['pop']
#
# 2UZIAOlrnyZmyzt1nuXr9y 1sdOQxBSDlGc922jSMhPVy
# Nicki Nicole
# Colocao - Tiny Desk
# ['argentine hip hop', 'r&b argentino', 'trap ar..']
#
# 4yrcVUvbTkZyhyVdsq5vsS 4HXYyIQSl8jCvvOo31bXMx
# Julian R. Fogel
# Tibidabo
# ['Uncategorized']
#
# 4yrcVUvbTkZyhyVdsq5vsS 5T1gpQGyqUMiKHmGBUAtHR
# Julian R. Fogel
# No entres ahí!
# ['Uncategorized']
#
# 2snm3HmsnDUDxbIChdl2Oj 0Hn9iSg0dwEfw7a7o8JjUZ
# Justin Hurwitz
# Welcome
# ['hollywood', 'movie tunes', 'soundtrack']
#
# 6M2wZ9GZgrQXHCFfjv46we 017PF4Q3l4DBUiWoXk4OWT
# Dua Lipa
# Break My Heart
# ['dance pop', 'pop', 'uk pop']
#
# 68Uwx1d3EbjDJhYsLjqvIq 39ncDMVidHOeQgeC5anYZM
# Series([], )
# Someone In The Crowd
# ['Uncategorized']
#
# 6M2wZ9GZgrQXHCFfjv46we 3AzjcOeAmA57TIOr9zF1ZW
# Dua Lipa
# Physical
# ['dance pop', 'pop', 'uk pop']
#
# 06HL4z0CvFAxyc27GXpf02 6AtZLIzUINvExIUy4QhdjP
# Taylor Swift
# I Knew You Were Trouble (Taylor's Version)
# ['pop']
#
# 2UZIAOlrnyZmyzt1nuXr9y 4A036RsBqPPMaGAcle29eO
# Nicki Nicole
# Mala Vida/Wapo Traketero - Tiny Desk
# ['argentine hip hop', 'r&b argentino', 'trap ar..']
#
# 348pk4o3EhKmsSahzuClSf 28Qkq4zVzDQpNgIb4r00lu
# Series([], )
# McFly
# ['Uncategorized']
#
# 6qqNVTkY8uBg9cP3Jd7DAH 6IRdLKIyS4p7XNiP8r6rsx
# Billie Eilish
# all the good girls go to hell
# ['art pop', 'electropop', 'pop']
#
# 66CXWjxzNUsdJxJ2JdwvnR 6Im9k8u9iIzKMrmV7BWtlF
# Ariana Grande
# 34+35
# ['pop']
#
# 66CXWjxzNUsdJxJ2JdwvnR 6ocbgoVGwYJhOv1GgI9NsF
# Ariana Grande
# 7 rings
# ['pop']
#
# 6zFYqv1mOsgBRQbae3JJ9e 4U45aEWtQhrm8A5mxPaFZ7
# Series([], )
# Vienna
# ['Uncategorized']
#
# 66CXWjxzNUsdJxJ2JdwvnR 3e9HZxeyfWwjeyPAMmWSSQ
# Ariana Grande
# thank u, next
# ['pop']
#
# 5cj0lLjcoR7YOSnhnX0Po5 748mdHapucXQri7IAO8yFK
# Series([], )
# Kiss Me More (feat. SZA)
# ['Uncategorized']
#
# 1GmsPCcpKgF9OhlNXjOsbS 6bpZMLiRQDm2XcjZudu3xV
# Lizzy McAlpine
# doomsday
# ['alt z', 'boston folk', 'indie pop']
#
# 6M2wZ9GZgrQXHCFfjv46we 1diS6nkxMQc3wwC4G1j0bh
# Dua Lipa
# We're Good
# ['dance pop', 'pop', 'uk pop']
#
# 6T70tWxqyIpdVbsFvPzqM3 5kRBzRZmZTXVg8okC7SJFZ
# Series([], )
# Another Day Of Sun
# ['Uncategorized']
#
# 2d0hyoQ5ynDBnkvAbJKORj 0tZ3mElWcr74OOhKEiNz1x
# Series([], )
# Bulls On Parade
# ['Uncategorized']
#
# 1McMsnEElThX1knmY4oliG 4ZtFanR9U6ndgddUvNcjcG
# Series([], )
# good 4 u
# ['Uncategorized']
#
# 6M2wZ9GZgrQXHCFfjv46we 39LLxExYz6ewLAcYrzQQyP
# Dua Lipa
# Levitating
# ['dance pop', 'pop', 'uk pop']
#
# 348pk4o3EhKmsSahzuClSf 02vK8PPOQPDcbxNe4YHdme
# Series([], )
# OUKE
# ['Uncategorized']
#
# 4yrcVUvbTkZyhyVdsq5vsS 6swFSkyUQ86vj5On35JFaD
# Julian R. Fogel
# Viento dile a la lluvia
# ['Uncategorized']
#
# 6qqNVTkY8uBg9cP3Jd7DAH 3XF5xLJHOQQRbWya6hBp7d
# Billie Eilish
# you should see me in a crown
# ['art pop', 'electropop', 'pop']
#
# 3kVUvbeRdcrqQ3oHk5hPdx 5d4ERnrRRe9o4I7aFLFTvP
# Series([], )
# Back in the 90's
# ['Uncategorized']
#
# 74KM79TiuVKeVCqs8QtB0B 1RAeuvRyRzCweAK3jUT0ZW
# Series([], )
# bet u wanna
# ['Uncategorized']
#
# 5rwUYLyUq8gBsVaOUcUxpE 5PEIORAOmwjDV7OYzxHsvd
# Lawrence
# Don't Lose Sight
# ['nyc pop', 'retro soul']
#
# 4yrcVUvbTkZyhyVdsq5vsS 6KGxpbD7KFnQWpIX67wRdP
# Julian R. Fogel
# A las Barricadas
# ['Uncategorized']
#
# 7mFiLle487vR83fsFmcKgt 3n5iTxuhweOCxLdQKn1qbz
# Himesh Patel
# I Saw Her Standing There - Tracks On The Tracks...
# ['Uncategorized']
#
# 6M2wZ9GZgrQXHCFfjv46we 3PfIrDoz19wz7qK7tYeu62
# Dua Lipa
# Don't Start Now
# ['dance pop', 'pop', 'uk pop']
#
# 06HL4z0CvFAxyc27GXpf02 0V3wPSX9ygBnCm8psDIegu
# Taylor Swift
# Anti-Hero
# ['pop']
#
# 5rwUYLyUq8gBsVaOUcUxpE 0PeMHmjYZTbQnWmQjYAM2k
# Lawrence
# Freckles
# ['nyc pop', 'retro soul']
#
# 6Di5PvWGKPYfwlLav6uNkP 0fcun9QJUPhiDEcDnadnxy
# Series([], )
# Son
# ['Uncategorized']
#
# 0cjQfBE89pEDpiylE0yp0V 7MfpfZynvDyiAfg9YmvsCl
# Series([], )
# My Dark World (Ecstasy the book)
# ['Uncategorized']
#
# 74KM79TiuVKeVCqs8QtB0B 6dgUya35uo964z7GZXM07g
# Series([], )
# Nonsense
# ['Uncategorized']
#
# 06HL4z0CvFAxyc27GXpf02 2Rk4JlNc2TPmZe2af99d45
# Taylor Swift
# ME! (feat. Brendon Urie of Panic! At The Disco)
# ['pop']
#
# 6M2wZ9GZgrQXHCFfjv46we 6uAFJ75WDAoAPyCWJAtvks
# Dua Lipa
# Good In Bed
# ['dance pop', 'pop', 'uk pop']
#
# 6kXm2YCtdUOpRYNKeKhfue 4r9hiElqKWMPT4Z3vN2exq
# Series([], )
# A Lovely Night
# ['Uncategorized']
#
# 06HL4z0CvFAxyc27GXpf02 1u8c2t2Cy7UBoG4ArRcF5g
# Taylor Swift
# Blank Space
# ['pop']
#
# 06HL4z0CvFAxyc27GXpf02 4R2kfaDFhslZEMJqAFNpdd
# Taylor Swift
# cardigan
# ['pop']
#
# 5rwUYLyUq8gBsVaOUcUxpE 1oRACEX7ci9IrxsbxfvAsw
# Lawrence
# It's Not All About You
# ['nyc pop', 'retro soul']
#
# 1GmsPCcpKgF9OhlNXjOsbS 3WP4iglY7SPmXucvNLJq2G
# Lizzy McAlpine
# erase me (feat. Jacob Collier)
# ['alt z', 'boston folk', 'indie pop']
#
# 7ltDVBr6mKbRvohxheJ9h1 1B0BQaSRHxhI0AUlItY3LK
# ROSALÍA
# MALAMENTE - Cap.1: Augurio
# ['pop', 'r&b en espanol']
#
# 5YGY8feqx7naU7z4HrwZM6 0yLdNVWF3Srea0uzk55zFn
# Series([], )
# Flowers
# ['Uncategorized']
#
# 6865jgnW89TIjWXr3Cuh33 1PyXioCJ8EmfxtZ5ajGX2O
# Shefa
# Modeh Ani
# ['Uncategorized']
#
# 4wsXXEmFF9uwQSOTFKZvs0 3Meap9iW6gLfrG7jzVlZxL
# Destruyan a Los Robots
# La Edad Que Tengo
# ['Uncategorized']

# %%
pd.set_option('display.max_rows', 100)
 
## AT THIS POINT IM GETTING A LOT OF 'SERIES' ARTISTS BECAUSE IM USING BOTH TOP LONG TERM DATAFRAMES, 
## BUT THEY DONT NECESSARILY COINCIDE IN THE ARTISTS THEY HAVE
## TO SOLVE THIS I SHOULD MAKE A MASTER REFERENCE DATAFRAME WHERE ALL NAMES ARE CHECKED

# Another option, to explore in a separate notebook, is to have code meant for 
# a graph that only shows genres and artists. That way the graph will also be less cluttered. 

sb_df = pd.DataFrame({"artist": final_artistlist, "track": final_tracklist, "genre": final_genrelist}) 
sb_df
# Out:
#                     artist                                              track
# 0                 Dua Lipa                                   Future Nostalgia  \
# 1                 Dua Lipa                                   Future Nostalgia
# 2                 Dua Lipa                                   Future Nostalgia
# 3             Taylor Swift                             Red (Taylor's Version)
# 73                Lawrence                             It's Not All About You
# 74          Lizzy McAlpine                     erase me (feat. Jacob Collier)
# 75          Lizzy McAlpine                     erase me (feat. Jacob Collier)
# 76          Lizzy McAlpine                     erase me (feat. Jacob Collier)
# 77                 ROSALÍA                         MALAMENTE - Cap.1: Augurio
# 78                 ROSALÍA                         MALAMENTE - Cap.1: Augurio
# 79            Series([], )                                            Flowers
# 80                   Shefa                                          Modeh Ani
# 81  Destruyan a Los Robots                                  La Edad Que Tengo
#
#                 genre
# 0           dance pop
# 1                 pop
# 2              uk pop
# 3                 pop
# 4                 pop
# 5   argentine hip hop
# 6       r&b argentino
# 7           trap ar..
# 8       Uncategorized
# 9       Uncategorized
# 10          hollywood
# 11        movie tunes
# 12         soundtrack
# 13          dance pop
# 14                pop
# 15             uk pop
# 16      Uncategorized
# 17          dance pop
# 18                pop
# 19             uk pop
# 20                pop
# 21  argentine hip hop
# 22      r&b argentino
# 23          trap ar..
# 24      Uncategorized
# 25            art pop
# 26         electropop
# 27                pop
# 28                pop
# 29                pop
# 30      Uncategorized
# 31                pop
# 32      Uncategorized
# 33              alt z
# 34        boston folk
# 35          indie pop
# 36          dance pop
# 37                pop
# 38             uk pop
# 39      Uncategorized
# 40      Uncategorized
# 41      Uncategorized
# 42          dance pop
# 43                pop
# 44             uk pop
# 45      Uncategorized
# 46      Uncategorized
# 47            art pop
# 48         electropop
# 49                pop
# 50      Uncategorized
# 51      Uncategorized
# 52            nyc pop
# 53         retro soul
# 54      Uncategorized
# 55      Uncategorized
# 56          dance pop
# 57                pop
# 58             uk pop
# 59                pop
# 60            nyc pop
# 61         retro soul
# 62      Uncategorized
# 63      Uncategorized
# 64      Uncategorized
# 65                pop
# 66          dance pop
# 67                pop
# 68             uk pop
# 69      Uncategorized
# 70                pop
# 71                pop
# 72            nyc pop
# 73         retro soul
# 74              alt z
# 75        boston folk
# 76          indie pop
# 77                pop
# 78     r&b en espanol
# 79      Uncategorized
# 80      Uncategorized
# 81      Uncategorized

# %%
fig = px.sunburst(sb_df, path=['artist', 'genre'])
fig.show()

# %%
lista1 = ["rock nacional", "rock pop", "rock latino", "pop","rock nacional", "rock pop", "rock latino", "pop", "pop", "pop", "pop", "folklore"] 
lista2 = ["fito", "fito", "fito", "fito", "charly", "charly", "charly", "charly", "ariana", "taylor", "abel pintos", "abel pintos"]
testdf = pd.DataFrame({"genero": lista1, "artista": lista2})
testdf

# %%
lista3 = ["fito", "charly", "ariana", "taylor", "abel"]
lista4 = [["rock nacional", "rock pop", "rock latino", "pop"], 
          ["rock nacional", "rock pop", "rock latino", "pop"],
          ["pop"],
          ["pop"],
          ["folklore", "pop"]]

testdf2 = pd.DataFrame({"artista": lista3, "genero": lista4})
testdf2

# %%
testfig = px.sunburst(testdf2, path=['genero', 'artista'])
testfig.show()

# %%
# intentar solo con datos de artistas
fig = px.sunburst(df_art, path=['genres', 'artist_name'])
fig.show()

# %%
tips = px.data.tips()
tips

# %%
fig = px.sunburst(tips, path=['day', 'time', 'sex', "smoker"], values='total_bill')
fig.show()

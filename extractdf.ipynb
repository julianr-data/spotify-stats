# %%
import pandas as pd

entity_type = "artist_id"
df_lt = pd.read_csv("DFLT.csv")
df_lt
# Out:
#     Unnamed: 0    type                artist_name
# 0            0  artist               Taylor Swift  \
# 1            1  artist                   Dua Lipa
# 2            2  artist              Ariana Grande
# 3            3  artist             Lizzy McAlpine
# 4            4  artist                  Fito Paez
# 5            5  artist             Justin Hurwitz
# 6            6  artist                    ROSALÍA
# 7            7  artist            Julian R. Fogel
# 8            8  artist                      Opeth
# 9            9  artist                   Vulfpeck
# 10          10  artist                The Beatles
# 11          11  artist                Mon Laferte
# 12          12  artist                   Lawrence
# 13          13  artist                  Cory Wong
# 14          14  artist            Rolando Alarcon
# 15          15  artist              Billie Eilish
# 16          16  artist             Britney Spears
# 17          17  artist              Charly García
# ...

# %%
ltids = open("LTIDS.txt", 'r')
listadelistas = [line.split() for line in ltids.readlines()]
ids = []

for lista in listadelistas:
    ids.append(lista[0])

print(ids)
# Out:
# ['06HL4z0CvFAxyc27GXpf02', '6M2wZ9GZgrQXHCFfjv46we', '66CXWjxzNUsdJxJ2JdwvnR', '1GmsPCcpKgF9OhlNXjOsbS', '1bZNv4q3OxYq7mmnLha7Tu', '2snm3HmsnDUDxbIChdl2Oj', '7ltDVBr6mKbRvohxheJ9h1', '4yrcVUvbTkZyhyVdsq5vsS', '0ybFZ2Ab08V8hueghSXm6E', '7pXu47GoqSYRajmBCjxdD6', '3WrFJ7ztbogyGnTHbHJFl2', '4boI7bJtmB1L3b1cuL75Zr', '5rwUYLyUq8gBsVaOUcUxpE', '6xt9sJmmyYwWkJv8A6ssiU', '1zVfOfIieOhrYPFXa6oMEt', '6qqNVTkY8uBg9cP3Jd7DAH', '26dSoYclwsYLMAKD3tpOr4', '3jO7X5KupvwmWTHGtHgcgo', '0k17h0D3J5VfsdmQ1iZtE9', '6mdiAmATAx73kdxrNrnlao', '0K59Fm1y7s3j498ueS4qzY', '5NXHXK6hOCotCF8lvGM1I0', '7mFiLle487vR83fsFmcKgt', '0fNbD2JQZjqtjThLWs4QMK', '2FFrhWZS9vJsh2UvxYPRr6', '4wsXXEmFF9uwQSOTFKZvs0', '5c3GLXai8YOMid29ZEuR9y', '0EmeFodog0BfCgMzAIvKQp', '2UZIAOlrnyZmyzt1nuXr9y', '2NPduAUeLVsfIauhRwuft1', '5WLsGgfxV206tL7KD41Ft1', '3z6Gk257P9jNcZbBXJNX5i', '1Yox196W7bzVNZI7RBaPnf', '3HrbmsYpKjWH1lzhad7alj', '5eAWCfyUhZtHHtBdNk56l1', '7An4yvF7hDYDolN4m5zKBp', '04gDigrS5kc9YWfZHwBETP', '4yNluGAiPbYXLwlA9KspbG', '1Mt6JeVW
# ...

# %%
# for idstring in ids:
#     print(df_lt.loc[df_lt[entity_type] == idstring, 'artist_name'])

df_lt.loc[df_lt[entity_type] == "1bZNv4q3OxYq7mmnLha7Tu", 'artist_name'].to_string(index=False)
# Out:
# 'Fito Paez'
